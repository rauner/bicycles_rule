# %% [markdown]
# # LCA for different transport modes with a focus on bicycles
#
# The notebook calculates the life cycle impacts for the EDGE_T internalization.
# * Calculate the energy requirement of powering bicycles
# * Calculate the impact of nutrition
# * Calculate the LCA impact of transport modes in EDGE_T
# * Add literature impacts of transport modes in EDGE_T
# * Output monetized impacts for EDGE_T internalization

# %%
#to-does:

# directly connect to carculator for the LCA processes to get different sizes and noise
# small scale version is to ask A for different sizes

# ebikes
## first add a couple of new bicycle processes that are a mix of cycles and ebikes
## big solution is to include ebikes into edget

# adjust preferance factor of non-motorized when ebikes are added 
# they should develop more like motorscooter?

# %%
# known issues

# LCA impacts are vehicle fleet averages, not differentiated really by LDV type, does favour big SUVs because load factor adjustment?
#  -> couple with carculator outputs

# carculator also delivers noise data

#liquids is only mapped to gasoline not diesel, bus is mapped to diesel
# buses assume EURO 6, only CH activity available

# we only consider person transport
# differentiate or add surrogate truck (eg.40t) for freight to get per vkm and add to all road processes

# plastic tire emissions not considered in cost

# %%
# fire up a connected console
# %qtconsole

# %%
import pickle
pickle.HIGHEST_PROTOCOL = 4
import pandas as pd
import numpy as np
import math as ma
import warnings
import matplotlib.pyplot as plt

import pprint
import brightway2 as bw
import bw2io
import seaborn as sn
import json
import copy

# %run -i ./script/helpers.py


warnings.filterwarnings('ignore')

###### run LCA script for a couple of years and interpolate in between

years = [2020, 2030, 2050]

#we only read contemporary bus data so far
bus_year = 2020

db_name = "ecoinvent_remind_Budg1100_ElecPush"
db_name_buses = "Mobitool - buses"


scenario = "bike-lca_lca_Budg1100_ElecPush"

# xxxx change to elecera plus lifestyle


#LCA database, REMIND, MAGPIE and air pollution data
remind_report        = "data\\remind\\Budg1100_ElecEra_2020-09-17_17.17.49\\REMIND_generic_Budg1100_ElecEra_withoutPlus.mif"
lca_database         = "data\\lca\\brightway2-project-bike-lca_lca_Budg1100_ElecPush-backup.22-January-2021-08-54PM.tar.gz"
magpie_report        = "data\\magpie\\magpie_C_SDP-PkBudg1100-mag-4.mif"
literature_report    = "data\\bicycles_rule_plot_source.csv"
air_pollution_report = "data\\air_pollution\\results_dalys_SSP2_Budg1100_ElecEra_SSP2_IIASA_aneris_downscaling_.csv"
region_mapping_path  = "data\\regionmappingH12.csv"

#EDGE_T data
edgetransport_moto_path       = "data\\edgeTransport\\UCD_NEC_iso.csv"
edgetransport_non_moto_path   = "data\\edgeTransport\\price_nonmot.csv"
edgetransport_load_factor_path= "data\\edgeTransport\\loadFactor.csv"

#Global Burden of Disease data
GBD_path             = "data\\GBD\\GBD.json"

gbd_location_mapping_path = "data\\GBD\\location_mapping.csv"
gbd_measure_mapping_path  = "data\\GBD\\measure_mapping.csv"
gbd_rei_mapping_path      = "data\\GBD\\rei_mapping.csv"
gbd_cause_mapping_path    = "data\\GBD\\cause_mapping.csv"
gbd_metric_mapping_path   = "data\\GBD\\metric_mapping.csv"

#Monetization

vsl_coeff_path            = "data\\monetization\\vsl_coeff.csv"

noise_eea_paths           = "data\\noise\\EEA_noise.csv"

#Carculator export

carculator_bus_path       = "data\\carculator\\buses_bw_ei_371.xlsx"

# %%
# read REMIND energy results
remind = pd.read_csv(remind_report, sep=';')

# %%
# read REMIND adjusted lci
bw.restore_project_directory(lca_database)
bw.projects.set_current(scenario)
bw.databases
# Out:
# Restoring project backup archive - this could take a few minutes...
# Databases dictionary with 8 object(s):
# 	biosphere3
# 	ecoinvent 3.7 cutoff
# 	ecoinvent_remind_Budg1100_ElecPush_2020
# 	ecoinvent_remind_Budg1100_ElecPush_2025
# 	ecoinvent_remind_Budg1100_ElecPush_2030
# 	ecoinvent_remind_Budg1100_ElecPush_2035
# 	ecoinvent_remind_Budg1100_ElecPush_2040
# 	ecoinvent_remind_Budg1100_ElecPush_2050

# %%
# read carculator bus specific LCI if not yet in databases
## link them to the year specific premis database

if db_name_buses not in bw.databases:
    
    ei_buses_db = bw2io.importers.excel.ExcelImporter(carculator_bus_path)
    ei_buses_db.apply_strategies()
    ei_buses_db.match_database(fields=["name", "unit", "location"])
    
        
    for year in years:
        ei_buses = copy.deepcopy(ei_buses_db)
        ei_buses.match_database(str(db_name) + "_" + str(year))
        ei_buses.add_unlinked_flows_to_biosphere_database()
        ei_buses.write_database()
        
        bw.Database(str(db_name_buses)).rename('Buses_' + str(year))
# Out:
# Extracted 1 worksheets in 115.39 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 0.40 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Vacuuming database
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:01
# Title: Writing activities to SQLite3 database:
#   Started: 10/07/2021 11:36:48
#   Finished: 10/07/2021 11:36:49
#   Total time elapsed: 00:00:01
#   CPU %: 69.00
#   Memory %: 5.49
# Applying strategy: link_iterable_by_fields
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# Title: Writing activities to SQLite3 database:
#   Started: 10/07/2021 11:38:36
#   Finished: 10/07/2021 11:38:40
#   Total time elapsed: 00:00:03
#   CPU %: 75.10
#   Memory %: 5.46
# Created database: Mobitool - buses
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# Title: Writing activities to SQLite3 database:
#   Started: 10/07/2021 11:40:16
#   Finished: 10/07/2021 11:40:19
#   Total time elapsed: 00:00:03
#   CPU %: 76.20
#   Memory %: 5.46
# Applying strategy: link_iterable_by_fields
# Vacuuming database
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:01
# Title: Writing activities to SQLite3 database:
#   Started: 10/07/2021 11:43:51
#   Finished: 10/07/2021 11:43:53
#   Total time elapsed: 00:00:01
#   CPU %: 63.80
#   Memory %: 5.51
# Applying strategy: link_iterable_by_fields
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# Title: Writing activities to SQLite3 database:
#   Started: 10/07/2021 11:45:46
#   Finished: 10/07/2021 11:45:50
#   Total time elapsed: 00:00:03
#   CPU %: 75.40
#   Memory %: 5.48
# Created database: Mobitool - buses
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# Title: Writing activities to SQLite3 database:
#   Started: 10/07/2021 11:47:25
#   Finished: 10/07/2021 11:47:28
#   Total time elapsed: 00:00:02
#   CPU %: 90.00
#   Memory %: 5.48
# Applying strategy: link_iterable_by_fields
# Vacuuming database
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:01
# Title: Writing activities to SQLite3 database:
#   Started: 10/07/2021 11:51:03
#   Finished: 10/07/2021 11:51:04
#   Total time elapsed: 00:00:01
#   CPU %: 77.40
#   Memory %: 5.28
# Applying strategy: link_iterable_by_fields
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:05
# Title: Writing activities to SQLite3 database:
#   Started: 10/07/2021 11:52:57
#   Finished: 10/07/2021 11:53:02
#   Total time elapsed: 00:00:05
#   CPU %: 85.30
#   Memory %: 5.22
# Created database: Mobitool - buses
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Title: Writing activities to SQLite3 database:
#   Started: 10/07/2021 11:54:38
#   Finished: 10/07/2021 11:54:42
#   Total time elapsed: 00:00:04
#   CPU %: 83.40
#   Memory %: 5.22

# %%
# fill a dict with the years lca databases
lca_databases={}
lca_databases_buses = {}
for year in years:
    lca_databases[str(year)]       = bw.Database(str(db_name) + "_" + str(year))
    lca_databases_buses[str(year)] = bw.Database('Buses_' + str(year))

# %%
#transport, passenger car, fleet average, {BEV, FCEV, ICEV-d, ICEV-p, ICEV-g, HEV-d, HEV-p, HEV-g, PHEV-d, PHEV-p, PHEV-g}, <year>, -d = Diesel, -p = Petrol, -g = Gas
#ES|Transport|VKM|Pass|Road|LDV|{BEV, FCEV, Gases, Hybrid Electric, Hybrid Liquids, Liquids}

# %% [markdown]
# ### Calculation of kcal/km bicycle
#
# The energy requirements of a bicycle are mainly determined by the gravity, rolling recistance, mechanic loss and, most importantly, aerodynamic drag.
#
# slope assumed to be zero since commutes begin and end at the same elevation.
# $\qquad F_{\mbox{gravity}} = g0 \sin(\arctan(\frac{s}{100})) w = 0 \\
# \text{where $g0$ = gravitational acceleration, $s$ = slope and $w$ = weight of rider and bike}$
#
# rolling resistance
# $\qquad F_{\mbox{rolling}} = g0 \cos(\arctan(\frac{s}{100})) w c_{r} \\
# \text{where $c_r$ = coefficient of rolling resistance}$
#
# Aerodynamic drag
# $\qquad F_{\mbox{aero}} = 0.5 c_{d} A \rho V^2 \\
# \text{where $c_{d}$ = drag coefficient, $A$ = frontal area, $\rho$= air density and $V$ is speed}$
#
# Power supply by rider:
# $\qquad P_{\mbox{rider}} = c_{b} \left[F_{\mbox{gravity}} + F_{\mbox{rolling}} + F_{\mbox{aero}}\right] V \\
# \text{where $c_{b}$ = bike efficiency, drivetrain losses and others}$
#
# Food intake:
# $\qquad E_{rider} = (P_{\mbox{rider}} \frac{d}{V}) \frac{1}{c_{m}} \\
# \text{where $d$ = distance, $c_{m}$ is the muscular efficiency}$
#
#
# do we need to give sources for formulas, they seem quite obvious
#
# Take Frontal Area and Drag Coeff from
# https://www.researchgate.net/publication/51660070_Aerodynamic_drag_in_cycling_Methods_of_assessment/link/00b49517f886174690000000/download
#
# Muscular efficiency:
# https://www.researchgate.net/publication/22014772_Muscular_efficiency_during_steady-rate_exercise_effects_of_speed_and_work_rate
#
# This gives around 15 kcal

# %%
ws2kcal = 1/4184
g0 = 9.8067 # m/s2
roh = 1.22601 # kg/m3

s = 0 # %
w = 75 # kg
a = 0.5 # m2

v = 4.16 # m/2 #15kmh from EDGE-T
d = 1000 # m

cr = 0.005
cd = 0.9
cb = 0.08
cm = 0.2


E_cycling = (((1-cb)*((g0*ma.sin(ma.atan(s/100))*w)+(g0*ma.cos(ma.atan(s/100))*w*cr)+(0.5*cd*a*roh*pow(v,2)))*v)*d/v)*1/cm * ws2kcal

print("{:.2f} kcal/km of food intake required for cycling 1km".format(E_cycling))

#see https://www.fitness-gesundheit.uni-wuppertal.de/fileadmin/fitness-gesundheit/pdf-Dokumente/Publikationen/2013/WasistMET_S.82-83.pdf
MET_minutes_cycling = E_cycling/1.2  
print("{:.2f} MET minutes required for cycling 1km".format(MET_minutes_cycling))
# Out:
# 9.29 kcal/km of food intake required for cycling 1km
# 7.74 MET minutes required for cycling 1km

# %%
# Add walking
# 

######### find good source of low kcal here. do the food requirements not outweight some effects
#check the environemntal cost

## decide what nutrition requirement is associated with walking one km
### simple approach is to use 75kcal as a good estimate for a body weight of 75kg according to the source below
E_walking = 75
MET_minutes_walking = E_walking/1.2 
print("{:.2f} kcal/km of food intake required for walking 1km".format(E_walking))
print("{:.2f} MET minutes required for walking 1km".format(MET_minutes_walking))

### elaborate appraoch would be to use:
#### take the regression model from https://journals.lww.com/nsca-jscr/Fulltext/2010/10000/Comparison_of_Energy_Expenditure_to_Walk_or_Run_a.29.aspx
#### read the kg average body weight from magpie and apply to this formula
#####E_walking = (mass (kg) × 0.789 - gender (men = 1, women = 2) × 7.634 + 51.109) / 1.6
# Out:
# 75.00 kcal/km of food intake required for walking 1km
# 62.50 MET minutes required for walking 1km

# %% [markdown]
# ### Diet to fuel cycling and ebike
#
# The diet plays a crucial role for the impact of bicycles. We model the nutrition demand and supply with the MAGPIE model. We use the same climate budget and assume a EAT-LANCET low waste diet adoption until 2050.

# %%
# Calculate a kcal share mix according to the MAGPIE results
# Calculate a demand/supply share
# Calulate the lca for that
cal2kj = 4.184

# %%
# fill a list with activities present in the magpie_ecoinvent_nutrition_mapping_simple
nutrition = {}

for year in years:
    #select which nutrition processes are included
    #determine their kg/kcal
    #see
    # %run -i ./script/diet_mappings.py
    
    activities=[]
    for value in magpie_ecoinvent_nutrition_mapping_extended.values():
        activities.append([act for act in lca_databases[str(year)] if act['name']==str(value).split("'",2)[1] and 'GLO' in act['location']][0])
    
    nutrition[str(year)] = lca_databases[str(year)].new_activity(code = 'nutrition'+ "_"  + str(year), name = "Nutrition mix "+ str(year) + ", EAT-Lancet diet convergance in 2050", unit = "kcal")

    print("the nutrition in " + str(year) +" consists of:")

    #loop over included nutition activities and add amount
    for i in range(len(activities)-1):
        act= str(activities[i])
        print(act)

        amt = magpie_intake.query("Variable == @act")[str(year)]
        amt = pd.to_numeric(amt, errors='coerce')
        if(ma.isnan(amt.values[0])):
            amt.values[0] = 0
        print(amt.values[0])

        nutrition[str(year)].new_exchange(input=activities[i].key,amount=amt.values[0],unit="kg/kcal",type='technosphere').save()

    nutrition[str(year)].save()
# Out:
# the nutrition in 2020 consists of:
# 'market for fishmeal, 65-67% protein' (kilogram, GLO, None)
# 5.7764412100456615e-06
# 'market for maize seed, organic, at farm' (kilogram, GLO, None)
# 1.0998780411672374e-05
# 'market for rice, non-basmati' (kilogram, GLO, None)
# 0.00013013846812434142
# 'market for wheat grain, feed' (kilogram, GLO, None)
# 3.930703565672844e-05
# 'market for peanut' (kilogram, GLO, None)
# 3.5061441496943787e-06
# 'market for apple' (kilogram, GLO, None)
# 0.0001015700737618546
# 'market for potato' (kilogram, GLO, None)
# 2.120457881159936e-05
# 'market for chickpea' (kilogram, GLO, None)
# 6.5417640610277596e-06
# 'market for potato' (kilogram, GLO, None)
# 2.120457881159936e-05
# 'market for sugar beet pulp' (kilogram, GLO, None)
# 8.760751831793565e-09
# 'market for sugar, from sugarcane' (kilogram, GLO, None)
# 3.7550693943763516e-07
# 'market for dairy' (cubic meter, GLO, None)
# 1.5431060154854075e-07
# 'chicken production' (kilogram, GLO, None)
# 1.1947115384615387e-05
# 'market for swine for slaughtering, live weight' (kilogram, GLO, None)
# 1.8708278451001055e-05
# 'chicken production' (kilogram, GLO, None)
# 1.1947115384615387e-05
# 'market for red meat, live weight' (kilogram, GLO, None)
# 1.8021741386467415e-05
# 'market for ethoxylated alcohol (AE11)' (kilogram, GLO, None)
# 1.2002859589041097e-05
# 'market for wheat grain, feed' (kilogram, GLO, None)
# 3.930703565672844e-05
# 'market for molasses, from sugar beet' (kilogram, GLO, None)
# 5.461738308927728e-09
# 'market for palm oil, refined' (kilogram, GLO, None)
# 1.4215428004710841e-05
# 'market for sugar, from sugarcane' (kilogram, GLO, None)
# 3.7550693943763516e-07
# the nutrition in 2030 consists of:
# 'market for fishmeal, 65-67% protein' (kilogram, GLO, None)
# 6.9908745247148295e-06
# 'market for maize seed, organic, at farm' (kilogram, GLO, None)
# 1.0389942877763694e-05
# 'market for rice, non-basmati' (kilogram, GLO, None)
# 0.00010836388157680935
# 'market for wheat grain, feed' (kilogram, GLO, None)
# 3.908248216903998e-05
# 'market for peanut' (kilogram, GLO, None)
# 7.664178754166081e-06
# 'market for apple' (kilogram, GLO, None)
# 0.00013447994865295248
# 'market for potato' (kilogram, GLO, None)
# 2.00564032503196e-05
# 'market for chickpea' (kilogram, GLO, None)
# 1.0348285396870104e-05
# 'market for potato' (kilogram, GLO, None)
# 2.00564032503196e-05
# 'market for sugar beet pulp' (kilogram, GLO, None)
# 5.109008557589333e-09
# 'market for sugar, from sugarcane' (kilogram, GLO, None)
# 2.162297378427056e-07
# 'market for dairy' (cubic meter, GLO, None)
# 1.5234767913888427e-07
# 'chicken production' (kilogram, GLO, None)
# 1.1301904685935106e-05
# 'market for swine for slaughtering, live weight' (kilogram, GLO, None)
# 1.384582886484027e-05
# 'chicken production' (kilogram, GLO, None)
# 1.1301904685935106e-05
# 'market for red meat, live weight' (kilogram, GLO, None)
# 1.3611761894398143e-05
# 'market for ethoxylated alcohol (AE11)' (kilogram, GLO, None)
# 8.647993240388679e-06
# 'market for wheat grain, feed' (kilogram, GLO, None)
# 3.908248216903998e-05
# 'market for molasses, from sugar beet' (kilogram, GLO, None)
# 3.3069650219250325e-09
# 'market for palm oil, refined' (kilogram, GLO, None)
# 1.7101171462052697e-05
# 'market for sugar, from sugarcane' (kilogram, GLO, None)
# 2.162297378427056e-07
# the nutrition in 2050 consists of:
# 'market for fishmeal, 65-67% protein' (kilogram, GLO, None)
# 5.967927536231884e-06
# 'market for maize seed, organic, at farm' (kilogram, GLO, None)
# 1.1830378170289854e-05
# 'market for rice, non-basmati' (kilogram, GLO, None)
# 0.00010285043478260871
# 'market for wheat grain, feed' (kilogram, GLO, None)
# 4.6241381074168796e-05
# 'market for peanut' (kilogram, GLO, None)
# 1.7195782532014418e-05
# 'market for apple' (kilogram, GLO, None)
# 0.0001936146321070234
# 'market for potato' (kilogram, GLO, None)
# 2.1150592885375495e-05
# 'market for chickpea' (kilogram, GLO, None)
# 1.9897791580400277e-05
# 'market for potato' (kilogram, GLO, None)
# 2.1150592885375495e-05
# 'market for sugar beet pulp' (kilogram, GLO, None)
# 0.0
# 'market for sugar, from sugarcane' (kilogram, GLO, None)
# 0.0
# 'market for dairy' (cubic meter, GLO, None)
# 1.0806710775047258e-07
# 'chicken production' (kilogram, GLO, None)
# 4.7337792642140466e-06
# 'market for swine for slaughtering, live weight' (kilogram, GLO, None)
# 2.243645484949833e-06
# 'chicken production' (kilogram, GLO, None)
# 4.7337792642140466e-06
# 'market for red meat, live weight' (kilogram, GLO, None)
# 3.4159420289855073e-06
# 'market for ethoxylated alcohol (AE11)' (kilogram, GLO, None)
# 0.0
# 'market for wheat grain, feed' (kilogram, GLO, None)
# 4.6241381074168796e-05
# 'market for molasses, from sugar beet' (kilogram, GLO, None)
# 0.0
# 'market for palm oil, refined' (kilogram, GLO, None)
# 1.9850009836710603e-05
# 'market for sugar, from sugarcane' (kilogram, GLO, None)
# 0.0

# %%
# Add new process which reflects the nutrition requirement of walking
walking = {}

for year in years:
    walking[str(year)] = lca_databases[str(year)].new_activity(code = 'walking' + '_' + str(year), name = "walking "+ str(year) + ", energy requirements", unit = "pkm")
    walking[str(year)].new_exchange(input=nutrition[str(year)],amount=E_walking,unit="kcal",type='technosphere').save()
    walking[str(year)].save()

# %% [markdown]
# ### Transport modes to perform LCA on

# %%
#transport modes to perform lca on
ecoinvent_activity_transport = {}
ecoinvent_activity_transport_bus = {}

for year in years:
    ecoinvent_activity_transport[str(year)] =        ["transport, passenger car, fleet average, BEV, "  + str(year),
                                                      "transport, passenger car, fleet average, FCEV, "   + str(year),
                                                      "transport, passenger car, fleet average, ICEV-g, "   + str(year),
                                                      "transport, passenger car, fleet average, PHEV-p, "   + str(year),
                                                      "transport, passenger car, fleet average, HEV-p, "   + str(year),
                                                      "transport, passenger car, fleet average, ICEV-p, "   + str(year),
                                                      "market for transport, passenger train", 
                                                      "market for transport, passenger, motor scooter",
                                                      "market for transport, passenger, bicycle",
                                                      "market for transport, passenger, electric bicycle",
                                                      "market for transport, passengers, aircraft, short haul",
                                                      "market for transport, passengers, aircraft, long haul",
                                                      "walking "+ str(year) + ", energy requirements"]

#bus transport modes
    ecoinvent_activity_transport_bus[str(year)] = ["transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, " + str(bus_year),
                                                   "transport, passenger bus, fuel cell electric, 18m articulated urban bus, " + str(bus_year),
                                                   "transport, passenger bus, diesel, 18m articulated urban bus, "+ str(bus_year) +", EURO-VI",
                                                   "transport, passenger bus, compressed gas, 18m articulated urban bus, "+ str(bus_year) +", EURO-VI"]

# %%
# fill a list with the relevant ecoinvent activities
# use the updated ecoinvent for cars and others
# use the bus database for buses

acti = {}
for year in years:

    acti_rest = {}
    acti_bus = {}

    for i in range(len(ecoinvent_activity_transport[str(year)])):
        activity = str(ecoinvent_activity_transport[str(year)][i])
        print(activity)
        
        ##### is this here a an unique identifier or we need to add one
    
        acti_rest[activity] = [act for act in lca_databases[str(year)] if activity in act["name"]]
    
        # fill a list with the relevant ecoinvent activities

        ##### bus activities are duplicated here, change to year specific data once available

    for i in range(len(ecoinvent_activity_transport_bus[str(year)])):
        activity = str(ecoinvent_activity_transport_bus[str(year)][i])
        print(activity)
    
        acti_bus[activity] = [act for act in lca_databases_buses[str(year)] if activity in act["name"]]

    #merge the two    
    acti[str(year)] = {**acti_rest, **acti_bus}
# Out:
# transport, passenger car, fleet average, BEV, 2020
# transport, passenger car, fleet average, FCEV, 2020
# transport, passenger car, fleet average, ICEV-g, 2020
# transport, passenger car, fleet average, PHEV-p, 2020
# transport, passenger car, fleet average, HEV-p, 2020
# transport, passenger car, fleet average, ICEV-p, 2020
# market for transport, passenger train
# market for transport, passenger, motor scooter
# market for transport, passenger, bicycle
# market for transport, passenger, electric bicycle
# market for transport, passengers, aircraft, short haul
# market for transport, passengers, aircraft, long haul
# walking 2020, energy requirements
# transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020
# transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020
# transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI
# transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI
# transport, passenger car, fleet average, BEV, 2030
# transport, passenger car, fleet average, FCEV, 2030
# transport, passenger car, fleet average, ICEV-g, 2030
# transport, passenger car, fleet average, PHEV-p, 2030
# transport, passenger car, fleet average, HEV-p, 2030
# transport, passenger car, fleet average, ICEV-p, 2030
# market for transport, passenger train
# market for transport, passenger, motor scooter
# market for transport, passenger, bicycle
# market for transport, passenger, electric bicycle
# market for transport, passengers, aircraft, short haul
# market for transport, passengers, aircraft, long haul
# walking 2030, energy requirements
# transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020
# transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020
# transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI
# transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI
# transport, passenger car, fleet average, BEV, 2050
# transport, passenger car, fleet average, FCEV, 2050
# transport, passenger car, fleet average, ICEV-g, 2050
# transport, passenger car, fleet average, PHEV-p, 2050
# transport, passenger car, fleet average, HEV-p, 2050
# transport, passenger car, fleet average, ICEV-p, 2050
# market for transport, passenger train
# market for transport, passenger, motor scooter
# market for transport, passenger, bicycle
# market for transport, passenger, electric bicycle
# market for transport, passengers, aircraft, short haul
# market for transport, passengers, aircraft, long haul
# walking 2050, energy requirements
# transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020
# transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020
# transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI
# transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI

# %%
# calculate the lci and lca for the activities in acti

# for LDV transfer kilometer to person kilometer
# for bikes and ebikes add nutrition

##### is this here an unique identifier or we need to introduce one?
###### check by just calculating this for 2020 and 2050 processes


lca = {}
impact_category = ('IPCC 2013', 'climate change', 'GWP 100a')

for year in years:

    for i in acti[str(year)]:
        print(i)
        
        for e in acti[str(year)][i]:
            print(e)
            
            if 'car' not in str(e):
                lca[str(year),e] = bw.LCA({e: 1}, (impact_category))
                
            if 'car' in str(e):
                lca[str(year),e] = bw.LCA({e: 1}, (impact_category))
                
            if 'passenger, bicycle' in e:
                lca[str(year),e] = bw.LCA({e: 1, nutrition[str(year)]: E_cycling}, (impact_category))   
        
        # this nutrition requirement is only an estimate, find better source
            if 'passenger, electric bicycle' in e:
                lca[str(year),e] = bw.LCA({e: 1, nutrition[str(year)]: 5}, (impact_category)) 

            lca[str(year),e].lci()
            lca[str(year),e].lcia()
            lca[str(year),e].score
            print(str(e) + ': '+  str(lca[str(year),e].score) + ' ' + str(impact_category))
# Out:
# transport, passenger car, fleet average, BEV, 2020
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, OAS, None): 0.35666643914867624 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, EUR, None): 0.2303584800533122 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, IND, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, IND, None): 0.37002416576716574 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, JPN, None): 0.2817022123587019 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, REF, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, REF, None): 0.36201421680174367 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, NEU, None): 0.20375253553994363 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, SSA, None): 0.2603173763105981 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, USA, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, USA, None): 0.3042546584592976 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, MEA, None): 0.27327394418392137 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, CAZ, None): 0.21841552320272659 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, CHA, None): 0.3141747771450534 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, BEV, 2020' (kilometer, LAM, None): 0.18276852934930116 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, FCEV, 2020
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, REF, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, REF, None): 0.43212432796423483 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, LAM, None): 0.4038513063048117 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, OAS, None): 0.4509679138679375 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, SSA, None): 0.3952852149811134 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, USA, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, USA, None): 0.4701476602180089 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, IND, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, IND, None): 0.37782833760508094 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, CHA, None): 0.39093915182239425 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, CAZ, None): 0.47543288950404716 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, JPN, None): 0.4171124698648785 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, MEA, None): 0.3898735318982509 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, NEU, None): 0.45245028395446496 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, FCEV, 2020' (kilometer, EUR, None): 0.43545327550413937 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, ICEV-g, 2020
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, LAM, None): 0.26932482034571037 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, CAZ, None): 0.32234077029456404 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, CHA, None): 0.24007588652655545 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, NEU, None): 0.10910962196413944 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, EUR, None): 0.28996145740035084 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, SSA, None): 0.07096252552660795 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, IND, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, IND, None): 0.25714906420856043 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, JPN, None): 0.2721780472384517 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, USA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, USA, None): 0.3212832348095257 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, OAS, None): 0.3010170161508904 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, REF, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, REF, None): 0.2893029477273111 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2020' (kilometer, MEA, None): 0.2619232463467094 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, PHEV-p, 2020
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, EUR, None): 0.3391848779693564 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, CHA, None): 0.3401227348471321 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, JPN, None): 0.3469658183468498 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, USA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, USA, None): 0.3777186115155831 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, REF, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, REF, None): 0.3610881462555032 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, MEA, None): 0.32053883608120537 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, OAS, None): 0.35799271590707776 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, NEU, None): 0.34347188744254403 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, LAM, None): 0.3073543213725253 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, CAZ, None): 0.3752376839955284 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, SSA, None): 0.3222777576425904 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, IND, None)
# 'transport, passenger car, fleet average, PHEV-p, 2020' (kilometer, IND, None): 0.3320679265931835 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, HEV-p, 2020
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, EUR, None): 0.2883829436153454 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, CAZ, None): 0.32506733483850214 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, NEU, None): 0.29570948683870946 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, LAM, None): 0.260687723470025 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, USA, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, USA, None): 0.3134473760048066 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, SSA, None): 0.2620029059388462 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, JPN, None): 0.28251480316067046 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, IND, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, IND, None): 0.25557971291272047 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, REF, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, REF, None): 0.2896466044276816 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, OAS, None): 0.2819192436626455 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, CHA, None): 0.26974068280776714 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, HEV-p, 2020' (kilometer, MEA, None): 0.2590070809903993 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, ICEV-p, 2020
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, IND, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, IND, None): 0.3199445034129846 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, USA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, USA, None): 0.39747474099846875 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, CHA, None): 0.3401938464111781 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, OAS, None): 0.3441426096855677 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, CAZ, None): 0.41272539388255247 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, EUR, None): 0.3650963302679231 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, LAM, None): 0.3319809820256131 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, MEA, None): 0.3336662966384514 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, JPN, None): 0.3595635221150524 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, NEU, None): 0.3770914009105104 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, REF, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, REF, None): 0.37277486632923496 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2020' (kilometer, SSA, None): 0.32446205867872313 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger train
# 'market for transport, passenger train' (person kilometer, GLO, None)
# 'market for transport, passenger train' (person kilometer, GLO, None): 0.05627414498709256 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger, motor scooter
# 'market for transport, passenger, motor scooter' (person kilometer, GLO, None)
# 'market for transport, passenger, motor scooter' (person kilometer, GLO, None): 0.15270096208588446 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger, bicycle
# 'market for transport, passenger, bicycle' (person kilometer, GLO, None)
# 'market for transport, passenger, bicycle' (person kilometer, GLO, None): 0.009224784685146585 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger, electric bicycle
# 'market for transport, passenger, electric bicycle' (person kilometer, GLO, None)
# 'market for transport, passenger, electric bicycle' (person kilometer, GLO, None): 0.019942018395783925 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'market for transport, passenger, electric bicycle, label-certified electricity' (person kilometer, GLO, None)
# 'market for transport, passenger, electric bicycle, label-certified electricity' (person kilometer, GLO, None): 0.016921741807815784 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passengers, aircraft, short haul
# 'market for transport, passengers, aircraft, short haul' (person kilometer, GLO, None)
# 'market for transport, passengers, aircraft, short haul' (person kilometer, GLO, None): 0.11982658448072424 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passengers, aircraft, long haul
# 'market for transport, passengers, aircraft, long haul' (person kilometer, GLO, None)
# 'market for transport, passengers, aircraft, long haul' (person kilometer, GLO, None): 0.09736597652270039 ('IPCC 2013', 'climate change', 'GWP 100a')
# walking 2020, energy requirements
# 'walking 2020, energy requirements' (pkm, GLO, None)
# 'walking 2020, energy requirements' (pkm, GLO, None): 0.06909047776688922 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020
# 'transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None)
# 'transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None): 0.0702755014281158 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020
# 'transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None)
# 'transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None): 0.13409078267877866 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI
# 'transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None)
# 'transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None): 0.09247812933414494 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI
# 'transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None)
# 'transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None): 0.059658449358922526 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, BEV, 2030
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, IND, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, IND, None): 0.1809728732949885 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, SSA, None): 0.11994160887877246 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, EUR, None): 0.1065167148305398 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, USA, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, USA, None): 0.1279482570214975 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, REF, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, REF, None): 0.17661673944382877 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, CAZ, None): 0.1066398894480377 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, LAM, None): 0.09455989527829382 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, NEU, None): 0.09718413182456287 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, CHA, None): 0.1360804071481436 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, JPN, None): 0.12645747932193216 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, MEA, None): 0.1501523697982392 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, BEV, 2030' (kilometer, OAS, None): 0.1762302427396646 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, FCEV, 2030
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, REF, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, REF, None): 0.14318509048223885 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, IND, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, IND, None): 0.12282461986232825 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, CAZ, None): 0.16055553187065805 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, CHA, None): 0.13255233007213996 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, EUR, None): 0.14363556651014406 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, SSA, None): 0.12345536532940152 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, NEU, None): 0.14746124731179264 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, JPN, None): 0.13834318176754776 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, USA, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, USA, None): 0.1566012143386515 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, OAS, None): 0.1447436175040989 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, LAM, None): 0.13258081762395682 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, FCEV, 2030' (kilometer, MEA, None): 0.13062126091518034 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, ICEV-g, 2030
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, CAZ, None): 0.2293996983793806 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, OAS, None): 0.20739486873281787 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, SSA, None): 0.08200950417497478 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, CHA, None): 0.1818102950057581 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, LAM, None): 0.20184569079201362 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, IND, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, IND, None): 0.19240910656630902 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, REF, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, REF, None): 0.16644568205205296 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, NEU, None): 0.042565542103216704 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, JPN, None): 0.06743566000890779 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, EUR, None): 0.0736862788163403 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, USA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, USA, None): 0.21532290478813707 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2030' (kilometer, MEA, None): 0.14214314441880496 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, PHEV-p, 2030
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, USA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, USA, None): 0.2702739247021131 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, JPN, None): 0.25726524289279 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, NEU, None): 0.2502220872983012 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, LAM, None): 0.23182462579644805 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, IND, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, IND, None): 0.25502537573388606 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, REF, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, REF, None): 0.27369353313376266 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, SSA, None): 0.23668669082153704 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, OAS, None): 0.25868883440514584 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, CAZ, None): 0.27496518503543504 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, EUR, None): 0.2435895420913301 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, CHA, None): 0.25721117626866863 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2030' (kilometer, MEA, None): 0.2473266459143961 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, HEV-p, 2030
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, NEU, None): 0.24306872593496687 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, REF, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, REF, None): 0.2424472338424843 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, OAS, None): 0.2232257910860655 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, SSA, None): 0.21463341709390965 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, MEA, None): 0.21684423723950005 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, EUR, None): 0.23262839038435607 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, CHA, None): 0.22721405457310775 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, USA, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, USA, None): 0.2582337538658594 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, LAM, None): 0.21895908584251927 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, JPN, None): 0.23505764050597622 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, CAZ, None): 0.2714703034742491 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, IND, None)
# 'transport, passenger car, fleet average, HEV-p, 2030' (kilometer, IND, None): 0.21385130636490907 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, ICEV-p, 2030
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, SSA, None): 0.2625769663793887 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, USA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, USA, None): 0.31298232621066846 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, EUR, None): 0.2873357267416619 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, IND, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, IND, None): 0.263602009213699 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, JPN, None): 0.2878526400104059 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, CAZ, None): 0.3301209713995786 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, MEA, None): 0.2658161125001372 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, OAS, None): 0.27319475366472323 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, NEU, None): 0.3005453562482852 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, CHA, None): 0.27990809644622366 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, REF, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, REF, None): 0.29932253635308487 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, ICEV-p, 2030' (kilometer, LAM, None): 0.26828630733177083 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger train
# 'market for transport, passenger train' (person kilometer, GLO, None)
# 'market for transport, passenger train' (person kilometer, GLO, None): 0.031960204285275795 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger, motor scooter
# 'market for transport, passenger, motor scooter' (person kilometer, GLO, None)
# 'market for transport, passenger, motor scooter' (person kilometer, GLO, None): 0.14339905018076032 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger, bicycle
# 'market for transport, passenger, bicycle' (person kilometer, GLO, None)
# 'market for transport, passenger, bicycle' (person kilometer, GLO, None): 0.006682453544639284 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger, electric bicycle
# 'market for transport, passenger, electric bicycle' (person kilometer, GLO, None)
# 'market for transport, passenger, electric bicycle' (person kilometer, GLO, None): 0.01243862866496281 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'market for transport, passenger, electric bicycle, label-certified electricity' (person kilometer, GLO, None)
# 'market for transport, passenger, electric bicycle, label-certified electricity' (person kilometer, GLO, None): 0.01083107145322293 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passengers, aircraft, short haul
# 'market for transport, passengers, aircraft, short haul' (person kilometer, GLO, None)
# 'market for transport, passengers, aircraft, short haul' (person kilometer, GLO, None): 0.11599198601810468 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passengers, aircraft, long haul
# 'market for transport, passengers, aircraft, long haul' (person kilometer, GLO, None)
# 'market for transport, passengers, aircraft, long haul' (person kilometer, GLO, None): 0.09631461757425162 ('IPCC 2013', 'climate change', 'GWP 100a')
# walking 2030, energy requirements
# 'walking 2030, energy requirements' (pkm, GLO, None)
# 'walking 2030, energy requirements' (pkm, GLO, None): 0.054942750146215656 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020
# 'transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None)
# 'transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None): 0.02873437545231171 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020
# 'transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None)
# 'transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None): 0.043152270347575 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI
# 'transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None)
# 'transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None): 0.08686786468839859 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI
# 'transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None)
# 'transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None): 0.05332219075685894 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, BEV, 2050
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, OAS, None): 0.06379365917157631 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, MEA, None): 0.0590227281881629 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, IND, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, IND, None): 0.054129624245687964 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, CAZ, None): 0.06752621657089265 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, CHA, None): 0.06647851086364073 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, REF, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, REF, None): 0.042074979652485606 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, NEU, None): 0.06057095962087991 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, SSA, None): 0.05480790713585638 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, EUR, None): 0.062123368255000935 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, USA, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, USA, None): 0.07016505244129087 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, JPN, None): 0.06097191798919998 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, BEV, 2050' (kilometer, LAM, None): 0.05845176049579965 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, FCEV, 2050
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, OAS, None): 0.06811201026738287 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, NEU, None): 0.07380428343339716 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, SSA, None): 0.06370455328929991 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, LAM, None): 0.06876852627374373 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, REF, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, REF, None): 0.07364603289061512 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, CHA, None): 0.06867285204608134 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, JPN, None): 0.07057471223123435 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, IND, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, IND, None): 0.0631169440661974 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, MEA, None): 0.06653641419909977 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, USA, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, USA, None): 0.08051394189559279 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, CAZ, None): 0.08232571468567888 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, FCEV, 2050' (kilometer, EUR, None): 0.0733740754455652 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, ICEV-g, 2050
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, IND, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, IND, None): 0.13444724618500997 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, CHA, None): 0.1470781011021592 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, USA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, USA, None): 0.049233532891835366 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, MEA, None): 0.06369037259667594 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, EUR, None): 0.03742840363852656 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, CAZ, None): 0.08298097017085423 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, JPN, None): 0.0445499817831113 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, SSA, None): 0.04802567809231964 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, NEU, None): 0.05511940883434638 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, REF, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, REF, None): 0.06905315439612006 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, LAM, None): 0.02444722200612333 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, ICEV-g, 2050' (kilometer, OAS, None): 0.08270753883137479 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, PHEV-p, 2050
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, OAS, None): 0.15930255599201648 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, CHA, None): 0.16791253303726833 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, JPN, None): 0.1675353699152161 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, LAM, None): 0.1568422163945979 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, SSA, None): 0.15808089883687315 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, USA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, USA, None): 0.17846361215503023 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, CAZ, None): 0.17525074334411503 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, NEU, None): 0.15885266685066202 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, EUR, None): 0.16019791102072434 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, MEA, None): 0.16433052055707367 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, REF, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, REF, None): 0.16386483398185359 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, IND, None)
# 'transport, passenger car, fleet average, PHEV-p, 2050' (kilometer, IND, None): 0.16229489853523157 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, HEV-p, 2050
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, NEU, None): 0.17991103805739017 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, CHA, None): 0.18012421441646634 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, EUR, None): 0.18005088673388725 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, OAS, None): 0.1740878921321286 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, JPN, None): 0.18387717203716458 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, SSA, None): 0.17238226144354024 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, MEA, None): 0.17920664486654328 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, CAZ, None): 0.20420828071718541 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, REF, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, REF, None): 0.19495004263160812 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, USA, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, USA, None): 0.20422541693005158 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, LAM, None): 0.1723335434576011 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, IND, None)
# 'transport, passenger car, fleet average, HEV-p, 2050' (kilometer, IND, None): 0.1762677556963183 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger car, fleet average, ICEV-p, 2050
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, USA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, USA, None): 0.22283254056638374 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, IND, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, IND, None): 0.18854707131873674 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, CHA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, CHA, None): 0.2003265456677539 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, OAS, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, OAS, None): 0.18522482689910486 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, JPN, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, JPN, None): 0.1971404399076602 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, NEU, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, NEU, None): 0.1911643034821527 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, CAZ, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, CAZ, None): 0.2192422907396991 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, MEA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, MEA, None): 0.19136867594042856 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, REF, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, REF, None): 0.20935040514143868 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, SSA, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, SSA, None): 0.18468829065853373 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, EUR, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, EUR, None): 0.19220720904105956 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, LAM, None)
# 'transport, passenger car, fleet average, ICEV-p, 2050' (kilometer, LAM, None): 0.1833093145784159 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger train
# 'market for transport, passenger train' (person kilometer, GLO, None)
# 'market for transport, passenger train' (person kilometer, GLO, None): 0.012943529651050565 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger, motor scooter
# 'market for transport, passenger, motor scooter' (person kilometer, GLO, None)
# 'market for transport, passenger, motor scooter' (person kilometer, GLO, None): 0.13632775685793888 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger, bicycle
# 'market for transport, passenger, bicycle' (person kilometer, GLO, None)
# 'market for transport, passenger, bicycle' (person kilometer, GLO, None): 0.00503015772738178 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passenger, electric bicycle
# 'market for transport, passenger, electric bicycle' (person kilometer, GLO, None)
# 'market for transport, passenger, electric bicycle' (person kilometer, GLO, None): 0.007809603770495953 ('IPCC 2013', 'climate change', 'GWP 100a')
# 'market for transport, passenger, electric bicycle, label-certified electricity' (person kilometer, GLO, None)
# 'market for transport, passenger, electric bicycle, label-certified electricity' (person kilometer, GLO, None): 0.0077162327843051095 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passengers, aircraft, short haul
# 'market for transport, passengers, aircraft, short haul' (person kilometer, GLO, None)
# 'market for transport, passengers, aircraft, short haul' (person kilometer, GLO, None): 0.11326068437485672 ('IPCC 2013', 'climate change', 'GWP 100a')
# market for transport, passengers, aircraft, long haul
# 'market for transport, passengers, aircraft, long haul' (person kilometer, GLO, None)
# 'market for transport, passengers, aircraft, long haul' (person kilometer, GLO, None): 0.09549597843308726 ('IPCC 2013', 'climate change', 'GWP 100a')
# walking 2050, energy requirements
# 'walking 2050, energy requirements' (pkm, GLO, None)
# 'walking 2050, energy requirements' (pkm, GLO, None): 0.03296398336962659 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020
# 'transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None)
# 'transport, passenger bus, battery electric - overnight charging, NCA battery, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None): 0.01614438787620997 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020
# 'transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None)
# 'transport, passenger bus, fuel cell electric, 18m articulated urban bus, 2020' (passenger-kilometer, CH, None): 0.019982141927638832 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI
# 'transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None)
# 'transport, passenger bus, diesel, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None): 0.08336885168269316 ('IPCC 2013', 'climate change', 'GWP 100a')
# transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI
# 'transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None)
# 'transport, passenger bus, compressed gas, 18m articulated urban bus, 2020, EURO-VI' (passenger-kilometer, CH, None): 0.04930418116143585 ('IPCC 2013', 'climate change', 'GWP 100a')

# %%
# plotting data preperation

def modes(lca):
    lca_impacts = {}
    fd   = pd.DataFrame()



    for i in lca:
      
        for m in methods:
        
            lca[i].switch_method(m)    
            lca[i].lcia()
            lca_impacts[m[2]] = lca[i].score

            
        full = pd.DataFrame.from_dict(lca_impacts, orient="index",  columns=[str(i)])
        fd[str(i)]=full[str(i)]
        
        fd.index.name = "indicator"
        fd.columns.name = "transport mode"
    return fd

# %%
methods = [m for m in bw.methods if "ReCiPe Endpoint (H) V1.13', 'ecosystem quality" in str(m) or "ReCiPe Endpoint (H) V1.13', 'human health" in str(m) or "ReCiPe Endpoint (H) V1.13', 'resources" in str(m)]
methods
# Out:
# [('ReCiPe Endpoint (H) V1.13', 'human health', 'human toxicity'),
#  ('ReCiPe Endpoint (H) V1.13', 'human health', 'climate change'),
#  ('ReCiPe Endpoint (H) V1.13', 'human health', 'ionising radiation'),
#  ('ReCiPe Endpoint (H) V1.13', 'human health', 'ozone depletion'),
#  ('ReCiPe Endpoint (H) V1.13', 'human health', 'particulate matter formation'),
#  ('ReCiPe Endpoint (H) V1.13',
#   'human health',
#   'photochemical oxidant formation'),
#  ('ReCiPe Endpoint (H) V1.13', 'ecosystem quality', 'marine ecotoxicity'),
#  ('ReCiPe Endpoint (H) V1.13', 'ecosystem quality', 'terrestrial ecotoxicity'),
#  ('ReCiPe Endpoint (H) V1.13',
#   'ecosystem quality',
#   'agricultural land occupation'),
#  ('ReCiPe Endpoint (H) V1.13', 'ecosystem quality', 'climate change'),
#  ('ReCiPe Endpoint (H) V1.13',
#   'ecosystem quality',
#   'freshwater eutrophication'),
#  ('ReCiPe Endpoint (H) V1.13', 'ecosystem quality', 'marine eutrophication'),
#  ('ReCiPe Endpoint (H) V1.13',
#   'ecosystem quality',
#   'natural land transformation'),
#  ('ReCiPe Endpoint (H) V1.13',
#   'ecosystem quality',
#   'terrestrial acidification'),
#  ('ReCiPe Endpoint (H) V1.13', 'ecosystem quality', 'urban land occupation'),
#  ('ReCiPe Endpoint (H) V1.13', 'resources', 'metal depletion'),
#  ('ReCiPe Endpoint (H) V1.13', 'resources', 'fossil depletion')]

# %%
data = modes(lca)

data.to_csv("results/impact_pkm.csv")

# %%
data.plot.bar()
plt.title('Impact [Vkm] in ' + str(year))
plt.savefig("plot/impact_pkm_"+str(year)+".pdf", bbox_inches='tight')

# %%
# calculate the air pollution of the relevant sectors LDV pass road and bus
air_pollution = pd.read_csv(air_pollution_report, sep=';')
# %run -i ./script/air_pollution_inter.py
data['transport mode'] = data['transport mode'].astype(str).str.split("\'").str[1]

# %%
# read in EDGE_results and for moto and non-moto

edgetransport_moto     = pd.read_csv(edgetransport_moto_path, sep=',')
edgetransport_non_moto = pd.read_csv(edgetransport_non_moto_path, sep=',')

edgetransport_moto     = edgetransport_moto[['year','region','vehicle_type', 'technology','non_fuel_price']]
edgetransport_non_moto = edgetransport_non_moto[['year','region','subsector_L3', 'technology','tot_price']]

edgetransport_moto = edgetransport_moto.rename(columns={"year":"period",'non_fuel_price':'cost'})
edgetransport_non_moto = edgetransport_non_moto.rename(columns={"year":"period",'subsector_L3':'vehicle_type','tot_price':'cost'})

edgetransport = edgetransport_moto.append(edgetransport_non_moto)

edgetransport['vehicle_type_technology'] = edgetransport['vehicle_type'].astype('string') + '_' + edgetransport['technology'].astype('string')

# %%
                                  
# read the edge transnsport output  

# %run -i ./script/mappings.py


#ultimately we need lca impact for edgetransport
# map edgetransport to LCA processes
edgetransport['LCA'] = edgetransport['vehicle_type_technology'].map(edge_internalization_mapping_detailed_LCA)





# then merge data to edgetransport
edgetransport_LCA = edgetransport.merge(data, left_on=['region','period', 'LCA'], right_on=['region','period','transport mode'], how='left')


###check it and iron out mistakes

# why is the bus processes missing? because its GLO
# filter NAN and merge with GLO processes without considering region

edgetransport_GLO = edgetransport.loc[edgetransport['LCA'].isin(data.loc[data['region'] == 'GLO']['transport mode'].unique())]

# adjust the global stuff??! with some proxy?

#take global values where region values are not available
edgetransport_GLO = edgetransport_GLO.merge(data.loc[data['region'] == 'GLO'], left_on=['period', 'LCA'], right_on=['period','transport mode'], how='left')

#edgetransport_GLO
edgetransport_GLO = edgetransport_GLO.drop(columns=['region_y'])
edgetransport_GLO = edgetransport_GLO.rename(columns={"region_x": "region"})


edgetransport_out = pd.concat([edgetransport_LCA,edgetransport_GLO])

# better version

# regional
## aggregate country processes to REMIND regions, take weighted averages
## if regional inventories are missing use GLO data

### do this here

# %%
# adjust the lca results to below
#consolidate columns
edgetransport_out = edgetransport_out.drop(columns=['transport mode'])
#,'GDP_scenario', 'EDGE_scenario',  'year'

# drop climate change here because we already capture it in the model with the CO2 price
# drop air pollution because we capture it with the more deatiled air pollution model
# drop cost from edgetransport
edgetransport_out = edgetransport_out.drop(columns=['cost','air_pollution_DALY','air_pollution_death','climate change','photochemical oxidant formation'])


# there are some duplicates with NAs, drop, not sure why
edgetransport_out = edgetransport_out.dropna()

# from wide to long
# include loadfactor only here and not above

edgetransport_out = pd.melt(edgetransport_out, id_vars=['region','period','vehicle_type','technology','vehicle_type_technology','LCA'],
        var_name="impact_category", 
        value_name="cost")

edgetransport_LCA = copy.deepcopy(edgetransport_out)


###### interpolate missing periods from the calculated Stützjahre years

# %% [markdown]
# # Calc indicators from literature

# %%
# this is the literature review of non-LCA impacts
literature = pd.read_csv(literature_report, sep=';')

#literature
#%run -i ./script/lit_inter.py

## we consider Road accidents, benfits from physical activity, noise  (health effets) and tire wear 

### Road accidents is based on the Global burden of disease (http://ghdx.healthdata.org/gbd-results-tool?params=gbd-api-2019-permalink/f50245689196c894965621f48bf542fd)
### Physical activity is based on the Global burden of disease and \cite{Lear2017}
### Noise is based on \cite{EuropeanEnvironmentAgency2020}

### Microplastics from tire wear is based on \cite{Evangeliou2020}

# %%
# load the GBD data and join it with mappings
# %run -i ./script/load_gbd.py

# low physical activity
# %run -i ./script/low_physical_activity.py
df_low
#rename value and unit for all of them
df_low =df_low.rename(columns={"value": "Value_low", "Unit": "Unit_low"})

# physical activity impacts are benefits
df_low['Value_low']= df_low['Value_low'] * -1


# assigne the benefit to bicycles and walking depending on their MET per pkm

# road safety
# %run -i ./script/road_safety.py
df_acc_remind
df_acc_remind =df_acc_remind.rename(columns={"value": "Value_acc", "Unit": "Unit_acc", "year": "Period", "remind": "Region"})



# noise
# %run -i ./script/noise.py
df_noise
df_noise =df_noise.rename(columns={"value": "Value_noise", "Unit": "Unit_noise", "year": "Period", "remind": "Region"})

# tire wear use this in the total processing
# %run -i ./script/tire_wear.py
remind_tire['Variable'] = 'Plastic emissions tires'
remind_tire =remind_tire.rename(columns={"value": "Value_tire_plastic", "Unit": "Unit_tire_plastice"})
remind_tire = remind_tire.drop(columns=['Region'])

# %%
# check what output format is needed
# then adjust the suff to this format
# read in EDGE_results and for moto and non-moto

#### here there should be duplicates introduced because we do not consider the technology
edgetransport_moto     = pd.read_csv(edgetransport_moto_path, sep=',')
edgetransport_non_moto = pd.read_csv(edgetransport_non_moto_path, sep=',')

edgetransport_moto     = edgetransport_moto[['year','region','vehicle_type','non_fuel_price']]
edgetransport_non_moto = edgetransport_non_moto[['year','region','subsector_L3','tot_price']]

edgetransport_moto = edgetransport_moto.rename(columns={"year":"period", "vehicle_type": "technology",'non_fuel_price':'cost'})
edgetransport_non_moto = edgetransport_non_moto.rename(columns={"year":"period",'subsector_L3':'technology','tot_price':'cost'})

edgetransport = edgetransport_moto.append(edgetransport_non_moto)



edgetransport['technology_low']   = edgetransport['technology'].map(edge_internalization_mapping_low)
edgetransport['technology_acc']   = edgetransport['technology'].map(edge_internalization_mapping_acc)
edgetransport['technology_noise'] = edgetransport['technology'].map(edge_internalization_mapping_noise)
edgetransport['technology_tires'] = edgetransport['technology'].map(edge_internalization_mapping_tire)

# %%
# literautre data is only from 1990 to 2019
# fill here the 2020 to 2100 in step 5 with NA for later interpolation

years = edgetransport['period'].unique()[edgetransport['period'].unique() > 2019]

def add_missing_years(df_in, value_column):

    for x in years:
        df = df_in.loc[df_in['Period'] == 2015]
        df['Period'] = x
        #use this to later interpolate
        #df[value_column] = 'NaN'
        
        
        df_in = pd.concat([df_in,df])
    return df_in

df_low = add_missing_years(df_low, 'Value_low')
df_acc_remind = add_missing_years(df_acc_remind, 'Value_acc')

# %%
#extrapolate to the future years for:
#interpolate stuff here
## this is not doing anything here since the above script already uses 2015 values for every after 2015
def interpolate_missing_years(df_in, value_column, unit_column):

    df_in[value_column] = pd.to_numeric(df_in[value_column], errors='coerce')
    df_in = df_in.pivot(index=['Region','Period',unit_column],columns = 'Variable', values=value_column)
    df_in = df_in.interpolate(method='linear')
    
    return df_in

df_low = interpolate_missing_years(df_low, 'Value_low', 'Unit_low')
df_acc_remind = interpolate_missing_years(df_acc_remind, 'Value_acc', 'Unit_acc')
df_noise = interpolate_missing_years(df_noise, 'Value_noise', 'Unit_noise')

#noise is already kept constant

# %%
df_low.pivot_table(values="Cycling", index="Period", columns="Region").plot()


df_noise.pivot_table(values="Road", index="Period", columns="Region").plot()
df_acc_remind.pivot_table(values="Motor vehicle road injuries", index="Period", columns="Region").plot()
df_acc_remind.pivot_table(values="Cyclist road injuries", index="Period", columns="Region").plot()
# Out:
# <AxesSubplot:xlabel='Period'>

# %%
# melt them from wide to long
df_acc_remind=df_acc_remind.reset_index()
df_acc_remind=pd.melt(df_acc_remind, id_vars=['Region','Period','Unit_acc'],
        var_name="Variable", 
        value_name="Value_acc",
        value_vars=['Cyclist road injuries', 'Motor vehicle road injuries','Motorcyclist road injuries'])

df_noise=df_noise.reset_index()
df_noise=pd.melt(df_noise, id_vars=['Region','Period','Unit_noise'],
        var_name="Variable", 
        value_name="Value_noise",
        value_vars=['Aircraft', 'Rail','Road'])

df_low=df_low.reset_index()
df_low=pd.melt(df_low, id_vars=['Region','Period','Unit_low'],
        var_name="Variable", 
        value_name="Value_low",
        value_vars=['Cycling'])

# %%
# put the literauter stuff together with edge transport
edgetransport = edgetransport.merge(remind_tire, left_on=['technology_tires'], right_on=['Variable'], how ='left', suffixes=(False, False))
edgetransport = edgetransport.drop(columns=['Variable'])

edgetransport = edgetransport.merge(df_low, left_on=['period', 'region', 'technology_low'], how ='left', right_on=['Period','Region','Variable'], suffixes=(False, False))
#remove region period and Variable
edgetransport = edgetransport.drop(columns=['Variable','Scenario','Period','Region'])

edgetransport = edgetransport.merge(df_acc_remind, left_on=['period', 'region', 'technology_acc'], how ='left', right_on=['Period','Region','Variable'], suffixes=(False, False))
edgetransport = edgetransport.drop(columns=['Variable','Period','Region'])

edgetransport_lit = edgetransport.merge(df_noise, left_on=['period', 'region', 'technology_noise'], how ='left', right_on=['Period','Region','Variable'], suffixes=(False, False))

# %%
# translate per capita in km
remind_population = remind[remind['Variable'] == 'Population']

remind_population    = remind_population.iloc[:, :-1]

remind_population = pd.melt(remind_population, id_vars=['Model','Scenario','Region' ,'Variable','Unit'], var_name='Period', value_name='value',ignore_index=True)
remind_population['Period'] = remind_population['Period'].astype(int)

edgetransport_lit = edgetransport_lit.merge(remind_population[['Period','Region','value']],  how='left',on = ['Region','Period'])

edgetransport_lit['Value_acc'] = edgetransport_lit['Value_acc'] * edgetransport_lit['value'] * (1*10**6) / (1*10**9)
edgetransport_lit['Unit_acc'] = 'DALY/vkm'
edgetransport_lit['Value_low'] = edgetransport_lit['Value_low'] * edgetransport_lit['value'] * (1*10**6) / (1*10**9)
edgetransport_lit['Unit_low'] = 'DALY/pkm MET'

### need to multiply MET rewuirements of cycling and walking for low physical activity

edgetransport_lit = edgetransport_lit.drop(['value'],axis=1)

edgetransport_lit['Value_noise'] = edgetransport_lit['Value_noise'] / (1*10**9)
edgetransport_lit['Unit_noise'] = 'DALY/vkm'
edgetransport_lit['Value_tire_plastic'] = edgetransport_lit['Value_tire_plastic'] / (1*10**9)
edgetransport_lit['Unit_tire_plastice'] = 'Mt/vkm'

#rename to more clear names
edgetransport_lit = edgetransport_lit.rename(columns={"Value_acc":"Road safety",'Value_low':'Physical Activity', 'Value_noise':'Noise', 'Value_tire_plastic': 'Microplastic tire t'})

#wide to long
##drop some columns
edgetransport_lit = edgetransport_lit.drop(['cost','Model','Unit_tire_plastice','Unit_low','Unit_acc','Region','Period','Unit_noise','technology_low','technology_acc','technology_noise','technology_tires','Variable'],axis=1)

edgetransport_lit = pd.melt(edgetransport_lit, id_vars=['region','period','technology'],
        var_name="impact_category", 
        value_name="cost")

# add vehicle type and vehicle_type_technology columns to fit LCA results
edgetransport_lit['vehicle_type']                 = edgetransport_lit['technology']
edgetransport_lit['vehicle_type_technology'] = edgetransport_lit['technology']

# %%
#merge LCA and literature output
edgetransport_write_out = pd.concat([edgetransport_lit,edgetransport_LCA])

# %%
# use load factor to translate to PKM

## adjust LCA results to pkm with car_load_factor or take the car load factor from edge
edgetransport_load_factor = pd.read_csv(edgetransport_load_factor_path, sep=',')

#merge byedgetransport_lit vegicle type
edgetransport_write_out =  edgetransport_write_out.merge(edgetransport_load_factor, left_on=['period', 'region', 'vehicle_type'], how ='left', right_on=['year','region','vehicle_type'], suffixes=(False, False))

######ebike is missing from load factor

#assigne load factor one to walking and cycling
edgetransport_write_out['loadFactor'][~edgetransport_write_out['vehicle_type'].str.contains('Cycle', na=False)] = 1
edgetransport_write_out['loadFactor'][~edgetransport_write_out['vehicle_type'].str.contains('Walk', na=False)] = 1

# divide by load factor
edgetransport_write_out['cost'] = edgetransport_write_out['cost']/ edgetransport_write_out['loadFactor']

# clean up
edgetransport_write_out = edgetransport_write_out.drop(columns=['year','loadFactor','GDP_scenario','EDGE_scenario'])

# %%
# monetize on endpoint


#mapping dict of mid-point to montetization method
## we consider DALYS for health and species.yr for environment, Ressources are already on USD level (USD2013)
edgetransport_write_out['impact_category_end'] = edgetransport_write_out['impact_category'].map(impact_category_mapping)

# load per DALY direct and indirect cost
# VSL from OECD (2012) Mortality risk valuation in environment, health and transport policies. OECD Publishing
# divded by the 2017 ration of mortality to DALYS, all cause all ages
# [$2005]

#u_DALY <- 3600000 / 25 


# HH_H [DALYS] = 144000  

# ED_H [species.yr] = 50447778 , Kiuk 2008 gives a value from the NEEDs project of 0.25 €2004/PDF/m2/year for the EU 25 based on restauration cost of from Germany to go from integreated arable to organic arable (the lowest cost to transform land)

# @Ott2007 gives a spatially weighted average to transform "Built Up Land" into
# other land for EU-25: 1.625 $2005/PDF/m2

# this equals 0.165 $2005/PDF/m2/year if we apply 10a for land-use change to last

# terrestrial species density: 1.48 E-8 [1/m2][3] global data from recipe
# 	CF PDF = SD PDF, only terrestrial
# 	CF [↕species.yr] = PDF.m2.yr * species/m²
# 	€/ CF [species.yr]= CF [↕species.yr] *1/( species/m²)
# 1/1.48 E-8 [1/m2] = 67567568 [1/(species/m²)]
# 0.165$ [2005] per m² per year * 67567568 [1/(species/m²)] = 1114864.87 $/species year


# RD_H [$] = 1.09

#EDGE needs 1990USD/pkm (1990USD/tkm for freight)
# 2005 - 1990 inflation = 0.63

#2020 - 1990 inflation = 0.49

# from wide to long edgetransport_out

# merge mapping

monetization_mapping = {'air_pollution_cost': 0.63,
                        'human health LCA':      144000    * 0.63,
                        
                        'human health':      144000    * 0.49,
                        
                        'ecosystem quality': 1114864.8 * 0.63,
                        'resources':         1.09      * 0.63,
                        
                       # what costs are associated with microplastic 
                        'Microplastic tire t': 0}

#

edgetransport_write_out['impact_category_end_cost'] = edgetransport_write_out['impact_category_end'].map(monetization_mapping)

edgetransport_write_out['cost'] =  edgetransport_write_out['impact_category_end_cost'] *edgetransport_write_out['cost'] 
edgetransport_write_out = edgetransport_write_out.drop(columns=['impact_category_end_cost'])

# %%
# unit transfer method to adjust monetization that is based on EUR values
# load monetization factors
vsl_coeff = pd.read_csv(vsl_coeff_path, sep = ';', index_col = 0) 
## condense to REMIND regions
### load region mapping

region_mapping = pd.read_csv(region_mapping_path, sep = ';', index_col = 0)

vsl_coeff = vsl_coeff.drop(columns=['Data2'])
vsl_coeff = pd.merge(vsl_coeff, region_mapping, left_on= "Region", right_on='CountryCode', how= "left")
vsl_coeff = vsl_coeff.groupby(['RegionCode','Year']).mean()
vsl_coeff = vsl_coeff.rename(columns={'Value': 'transfer'})

# merge with edgetransport_out and multiply
edgetransport_write_out = pd.merge(edgetransport_write_out, vsl_coeff, left_on= ["region",'period'], right_on=['RegionCode','Year'], how= "left")

edgetransport_write_out['cost'] =  edgetransport_write_out['transfer'] *edgetransport_write_out['cost'] 
edgetransport_write_out = edgetransport_write_out.drop(columns=['transfer'])

edgetransport_write_out = edgetransport_write_out.drop_duplicates()

#how to deal with missing values for certain years
#### tire?


############ add ebikes as a share of bikes, make a couple of shares as different cycle processes
##### ebikes are lost somewhere above in the literaure script, check

# %%
# write out in EDGE format
